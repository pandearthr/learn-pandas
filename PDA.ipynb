# %%
import pandas as pd
df = pd.read_csv("baju_thriftingg.csv", encoding='latin1')
df.shape
df.info()

# %%
df.isnull().sum()

# %%
df.duplicated(subset='full_text').sum()

# %%
df['lang'].value_counts()

# %%
df['tweet_length'] = df['full_text'].astype(str).apply(lambda x: len(x.split()))
df['tweet_length'].describe()

# %%
from collections import Counter
words = " ".join(df['full_text'].astype(str)).split()
Counter(words).most_common(20)

# %%
df['full_text'].sample(5, random_state=7)
